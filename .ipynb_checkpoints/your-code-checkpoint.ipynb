# %% [markdown]
# # Lab: Regression Analysis

# %% [markdown]
# ### Before you start:
#
# * Read the README.md file
# * Comment as much as you can and use the resources (README.md file)
#
# Happy learning!

# %% [markdown]
# ## Challenge 1
# I work at a coding bootcamp, and I have developed a theory that the younger my students are, the more often they are late to class. In order to test my hypothesis, I have collected some data in the following table:
#
# | StudentID | Age | Tardies |
# |--------|-----|------------|
# | 1      | 17  | 10         |
# | 2      | 51  | 1          |
# | 3      | 27  | 5          |
# | 4      | 21  | 9         |
# | 5      | 36  |  4         |
# | 6      | 48  |  2         |
# | 7      | 19  |  9         |
# | 8      | 26  | 6          |
# | 9      | 54  |  0         |
# | 10     | 30  |  3         |

# %% [markdown]
# Use this command to create a dataframe with the data provided in the table.
# ~~~~
# student_data = pd.DataFrame({'X': [x_values], 'Y': [y_values]})
# ~~~~

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
student_data = pd.DataFrame({'X': [17,51,27,21,36,48,19,26,54,30], 'Y': [10,1,5,9,4,2,9,6,0,3]})

# %% [markdown]
# Draw a dispersion diagram (scatter plot) for the data.

# %%
sns.scatterplot(data=student_data,x='X',y='Y')
# Out:
# <AxesSubplot:xlabel='X', ylabel='Y'>

# %% [markdown]
# Do you see a trend? Can you make any hypotheses about the relationship between age and number of tardies?

# %%
#Parece haber una línea decreciente que implicac que a mayor edad menos faltas de asistencia

# %% [markdown]
# Calculate the covariance and correlation of the variables in your plot. What is the difference between these two measures? Compare their values. What do they tell you in this case? Add your responses as comments after your code.

# %%
cov=student_data.cov()
corr=student_data.corr()
'''
1) La correlación entre X e Y es -0,939 y nos dice que hay casi una correlación negativa lineal entre las dos variables, es decir
por 1 unidad más de X habrá 0,94 unidad menos de Y
2) La correlación es la versión normalizada de la covarianza. La covarianza entre X e Y es -45,57 y nos indica el grado de variación
conjunta de X e Y respectos a sus medias. Como es negativa interpretamos que los valores altos de X se corresponden con los valores
bajos de Y
https://es.wikipedia.org/wiki/Covarianza
'''
# Out:
# '\n1) La correlación entre X e Y es -0,939 y nos dice que hay casi una correlación negativa lineal entre las dos variables, es decir\npor 1 unidad más de X habrá 0,94 unidad menos de Y\n2) La correlación es la versión normalizada de la covarianza. La covarianza entre X e Y es -45,57 y nos indica el grado de variación\nconjunta de X e Y respectos a sus medias. Como es negativa interpretamos que los valores altos de X se corresponden con los valores\nbajos de Y\nhttps://es.wikipedia.org/wiki/Covarianza\n'

# %% [markdown]
# Build a regression model for this data. What will be your outcome variable? What type of regression are you using? Add your responses as comments after your code.

# %%
x=student_data['X'].tolist()
y=student_data['Y'].tolist()
#calculamos el scope
m = corr.at['X','Y'] * (np.std(y)/np.std(x))
#calculamos el intercept
b = np.mean(y) - m * np.mean(x)
#creamos el modelo de regresión lineal donde y_1 es la variable dependiente (outcome variable) y x_1 es la variable independiente
y_1 = b + m * x_1
#testeamos
x_1=25
y_1 = b + m * x_1
y_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-cbf9c0d6ce2b> in <module>
#       6 b = np.mean(y) - m * np.mean(x)
#       7 #creamos el modelo de regresión lineal donde y_1 es la variable dependiente (outcome variable) y x_1 es la variable independiente
# ----> 8 y_1 = b + m * x_1
#       9 #testeamos
#      10 x_1=25
#
# NameError: name 'x_1' is not defined

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
x=student_data[['X']]
y=student_data['Y']
model.fit(x, y)
model.score(x,y)
# Out:
# 0.8820265558250109

# %% [markdown]
# Plot your regression model on your scatter plot.

# %%
#valores consecutivos entre 17 y 55 años
x_1 = np.linspace(17,55,39)
y_1 = b + m * x_1
plt.scatter(x,y)
plt.plot(x_1, y_1, c='r')

# %% [markdown]
# Interpret the results of your model. What can conclusions can you draw from your model and how confident in these conclusions are you? Can we say that age is a good predictor of tardiness? Add your responses as comments after your code.

# %%
R2=stats.pearsonr(student_data['X'], student_data['Y'])[0]**2
f'Según el modelo a mayor edad menores faltas de asistencias. El modelo predice un {R2*100}% de la disminución en las faltas de asistencia a año addicional'
# Out:
# 'Según el modelo a mayor edad menores faltas de asistencias. El modelo predice un 88.20265558250108% de la disminución en las faltas de asistencia a año addicional'

# %% [markdown]
# ## Challenge 2
# For the second part of this lab, we will use the vehicles.csv data set. You can find a copy of the dataset in the git hub folder. This dataset includes variables related to vehicle characteristics, including the model, make, and energy efficiency standards, as well as each car's CO2 emissions. As discussed in class the goal of this exercise is to predict vehicles' CO2 emissions based on several independent variables.

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv('vehicles.csv')

# %% [markdown]
# Let's use the following variables for our analysis: Year, Cylinders, Fuel Barrels/Year, Combined MPG, and Fuel Cost/Year. We will use 'CO2 Emission Grams/Mile' as our outcome variable.
#
# Calculate the correlations between each of these variables and the outcome. Which variable do you think will be the most important in determining CO2 emissions? Which provides the least amount of helpful information for determining CO2 emissions? Add your responses as comments after your code.

# %%
sns.pairplot(data=data,
            y_vars=['Year','Cylinders','Fuel Barrels/Year','Combined MPG','Fuel Cost/Year'],
            x_vars=['CO2 Emission Grams/Mile'])

#Fuel Cost/Year y Fuel Barrels/Year son las que paracen tener mayor correlacion con CO2 Emission Grams/Mile

# %% [markdown]
# Build a regression model for this data. What type of regression are you using? Add your responses as comments after your code.

# %%
import statsmodels.api as sm
model=sm.OLS(y,x).fit()
x=data[['Year','Cylinders','Fuel Barrels/Year','Combined MPG','Fuel Cost/Year']]
y=data['CO2 Emission Grams/Mile']

#mi regresion es la lineal

# %% [markdown]
# Print your regression summary, and interpret the results. What are the most important varibles in your model and why? What can conclusions can you draw from your model and how confident in these conclusions are you? Add your responses as comments after your code.

# %%
print(model.summary())
#teniendo en cuenta sus coeficientes las variables más importantes del modelo son "Fuel Barrels/Year" en correlacion positiva y "Combined MPG" en correlacion negativa
#R-squared es igual a 999%, es decir los cambios en las variables independients explican un 99,9% los cambios en la variable dependiente.
#Por tanto, podemos estar muy seguros.
#https://medium.com/swlh/interpreting-linear-regression-through-statsmodels-summary-4796d359035a

# %% [markdown]
# ## Bonus Challenge: Error Analysis

# %% [markdown]
# I am suspicious about the last few parties I have thrown: it seems that the more people I invite the more people are unable to attend. To know if my hunch is supported by data, I have decided to do an analysis. I have collected my data in the table below, where X is the number of people I invited, and Y is the number of people who attended.
#
# |  X |  Y |
# |----|----|
# | 1  |  1 |
# | 3  |  2 |
# | 4  |  4 |
# | 6  |  4 |
# | 8  |  5 |
# | 9  |  7 |
# | 11 |  8 |
# | 14 |  13 |

# %% [markdown]
# We want to know if the relationship modeled by the two random variables is linear or not, and therefore if it is appropriate to model it with a linear regression.
# First, build a dataframe with the data.

# %%
df = pd.DataFrame({'X': [1,3,4,6,8,9,11,14], 'Y': [1,2,4,4,5,7,8,13]})

# %% [markdown]
# Draw a dispersion diagram (scatter plot) for the data, and fit a regression line.

# %%
sns.lmplot(data=df, x='X', y='Y')

# %% [markdown]
# What do you see? What does this plot tell you about the likely relationship between the variables? Print the results from your regression.

# %%
#Vemos una correlación lineal positiva entre X e Y. Cuanto más X (gente invito) más Y (gente que asiste).
stats.linregress(df['X'], df['Y'])
# Out:
# LinregressResult(slope=0.8484848484848485, intercept=-0.43939393939393945, rvalue=0.9652303546573691, pvalue=0.00010236374464090686, stderr=0.09380896778286217, intercept_stderr=0.7592153973608793)

# %% [markdown]
# Do you see any problematic points, or outliers, in your data? Remove these points and recalculate your regression. Print the new dispersion diagram with your new model and the results of your model.

# %%
#según la función z_scores ninguno de los valores es un outlier"
'''z_scores = stats.zscore(df)
abs_z_scores = np.abs(z_scores)
filtered_entries = (abs_z_scores < 3).all(axis=1)
new_df = df[filtered_entries] #es la misma que df'''
df=df.drop([2,4,7])
sns.lmplot(data=df, x='X', y='Y')
stats.linregress(df['X'], df['Y'])
# Out:
# LinregressResult(slope=0.7352941176470588, intercept=-0.011764705882352011, rvalue=0.9941320562302279, pvalue=0.0005391134182578607, stderr=0.046193015644666366, intercept_stderr=0.3253247866973561)

# %% [markdown]
# What changed? Based on the results of the two models and your graphs, what can you say about the form of the data with the problematic point and without it?

# %%
#hay una mayor correlación en el segundo modelo que en el primero pero el p_value es menor porque hay menos valores y por tanto la confianza en la previsión será menor
